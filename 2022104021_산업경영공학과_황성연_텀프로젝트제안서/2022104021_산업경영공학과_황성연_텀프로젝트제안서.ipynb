# %% [markdown]
# (1) 주제 선정 이유: 왜 이 주제(분야)를 선정하게 된 이유를 나열함
# 내가 선정한 주제는 '미세먼지 농도와 주가의 상관관계를 발견해보자'이다. 산업경영공학과에 재학중인 나는 금융공학에 관심을 가지게 되었다. 이 텀프로젝트는 어쩌면 앞으로 수없이 많이 하게될 증시관련 데이터의 첫번째 분석이다. 부디 의미있는 결론이 나왔으면 한다.
# (2) 가설 정의: 본인이 Term 프로젝트를 통해서 증명하고자 하는 명제 혹은 밝히고자 하는 논리가 무엇인지 설명함
# 미세먼지 농도가 높은 시기가 사람들의 주식 매수/매도 심리, 생활패턴, 소비패턴을 변화시켜 주가에 어떤식으로든 영향을 줄 것이라고 예상한다. 데이터 분석으로 증명하고 싶은 예상되는 영향을 예로 들자면 미세먼지가 높은 날엔 사람들의 야외활동이 줄어 방송통신 분야 지수는 상승하고 경기소비재와 전체적인 kospi 및 kosdaq의 주가는 하락하는 것이다. 다만 주가라는 것은 당연히 엄청나게 많은 변동 요인을 가지고 있기에 정확히 미세먼지와의 상관관계를 밝히는 것에 실패할지도 모른다.
# (3) 인터넷을 통한 데이터 획득: 위의 명제/논리을 펼치기 위하여, 어디서 Python을 통해 어떻게 데이터를 획득했는지 구체적으로 나열함
# 자료: 주가지수 월별 추이(krx,kospi,kosdaq)
# 출처: krx 정보데이터시스템
# http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0301
#
# 자료: 미세먼지 월별 도시별 대기오염도
# 출처: 환경부 환경통계포털
# https://stat.me.go.kr/portal/stat/easyStatPage.do
# (4) 분석을 위한 데이터의 가공: 데이터는 가공되지 않으면 의미가 없으므로, 어떻게 어떤 정보를 Python으로 추출했는지 설명함
# 가공 예정
# (5) 분석 결과 도출: 수학적 방법 혹은 논리적 방법을 Python으로 구현함으로서, 프로그램을 통해서 결과를 도출함
# 도출 예정
# (6) 결론: 본인의 명제/논리가 증명/확인 되었는지와 이를 구체적으로 서술함
# 도출 예정
# (7) 참고문헌: 위의 작업을 위하여 획득한 자료, 인터넷 정보, 논문, 도서 등을 나열함
# 2010년 1월 ~ 2019년 12월의 krx, kospi, kosdaq, 서울특별시 미세먼지(PM10,PM2.5) 엑셀자료.
# *krx파일중 용량이 8KB인것은 2016년 9월부터의 자료임
# 미세먼지(PM2.5)는 2015년 1월부터의 자료임
# 나머지는 모두 2010년 1월부터 2019년 12월까지의 자료임*
# (8) 별첨: (3)의 획득한 데이터 원본
# 별도 첨부함
# (9) 별첨: (4)의 가공된 데이터 원본
# 아직 가공하지 않음
# (10) 별첨: (3)을 (4)로 변환하는 등의 작업을 위하여 본인이 직접 개발한 Python 소스코드 원본
# 아직 작성하지 않음
